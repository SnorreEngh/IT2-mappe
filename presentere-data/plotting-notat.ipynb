# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
def f(x):
    return 3*x**2

# %%
x = []
y = []
for i in range(20):
    x.append(i)
    y.append(f(i))

# %%
plt.plot(x, y)
plt.show()

# %%
x = np.linspace(0, 200, 10)
y = f(x)

# %%
plt.plot(x, y)
plt.style.use("_classic_test_patch")
plt.title("$f(x) = 3x^2$")
plt.xlabel("$x$")
plt.ylabel("$y$")
plt.show()

# %%
#plt.style.available
